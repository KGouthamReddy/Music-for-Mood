# %% [markdown]
# <center><h2> Project : Music For Mood </h2></center

# %% [markdown]
# <h2>Trail 1: tesing the functionality</h2>

# %%
from deepface import DeepFace
import cv2
#[angry,fear,neutral,sad,disgust,happy,surprise]

# %%
import matplotlib.pyplot as plt

# %%
# random images

img1=cv2.imread('girl.jpg')
img2=cv2.imread('girl2.jpg')
img3=cv2.imread('random_img.jpg')

# %%
plt.imshow(img1[:,:,::-1])
plt.xlabel('img1')
plt.show()

# %%
plt.imshow(img2[:,:,::-1])
plt.xlabel('img2')
plt.show()

# %%
plt.imshow(img3[:,:,::-1])
plt.xlabel('img3')
plt.show()

# %%
img1_result = DeepFace.analyze(img1, actions = ['emotion'])

# %%
img2_result = DeepFace.analyze(img2, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000023CF8985430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000023CF8814670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
img3_result = DeepFace.analyze(img3, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000023CF680C820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 20 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000023CF67E64C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(img1_result)
# Out:
# {'emotion': {'angry': 4.736228616269253e-05, 'disgust': 2.1413715114470287e-20, 'fear': 0.005454897070642013, 'happy': 5.127595320881448e-08, 'sad': 4.3843715995352615e-10, 'surprise': 99.99449849095932, 'neutral': 1.203913950070399e-09}, 'dominant_emotion': 'surprise'}

# %% [markdown]
# #

# %%
print(img2_result)
# Out:
# {'emotion': {'angry': 7.3359880670142985e-09, 'disgust': 8.23456971013603e-13, 'fear': 4.450583781720474e-11, 'happy': 99.99922513961792, 'sad': 4.8518938866592976e-08, 'surprise': 5.457500770744694e-09, 'neutral': 0.000774942418502178}, 'dominant_emotion': 'happy'}

# %%
print(img3_result)
# Out:
# {'emotion': {'angry': 0.003756692967726849, 'disgust': 1.3671177079288555e-06, 'fear': 0.08385449182242155, 'happy': 9.299663454294205, 'sad': 0.19030297407880425, 'surprise': 0.003676019696285948, 'neutral': 90.41874408721924}, 'dominant_emotion': 'neutral'}

# %%
print(img1_result['dominant_emotion'])
# Out:
# surprise

# %%
print(img2_result['dominant_emotion'])
# Out:
# happy

# %%
print(img3_result['dominant_emotion'])
# Out:
# neutral
