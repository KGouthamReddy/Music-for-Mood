# %% [markdown]
# <center><h2> Project : Music For Mood </h2></center

# %% [markdown]
# <h2>Trail 2 </h2>

# %%
from deepface import DeepFace
import cv2
#[angry,fear,neutral,sad,disgust,happy,surprise]

# %%
import matplotlib.pyplot as plt

# %%
# testing female face expressions
img1=cv2.imread('angry.jpg')
img2=cv2.imread('fear.jpg')
img3=cv2.imread('happy.jpg')
img4=cv2.imread('sad.jpg')
img5=cv2.imread('surprise.jpg')
img6=cv2.imread('disgust.jpg')
img7=cv2.imread('neutral.jpg')

# %%
plt.imshow(img1[:,:,::-1])
plt.xlabel('img1')
plt.show()

# %%
plt.imshow(img2[:,:,::-1])
# plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.xlabel('img2')
plt.show()

# %%
plt.imshow(img3[:,:,::-1])
plt.xlabel('img3')
plt.show()

# %%
plt.imshow(img4[:,:,::-1])
plt.xlabel('img4')
plt.show()

# %%
plt.imshow(img5[:,:,::-1])
plt.xlabel('img5')
plt.show()

# %%
plt.imshow(img6[:,:,::-1])
plt.xlabel('img6')
plt.show()

# %%
plt.imshow(img7[:,:,::-1])
plt.xlabel('img7')
plt.show()

# %%
img1_result = DeepFace.analyze(img1, actions = ['emotion'])

# %%
img2_result = DeepFace.analyze(img2, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FDB8F38550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
img3_result = DeepFace.analyze(img3, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 24 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FDB4F3C3A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
img4_result = DeepFace.analyze(img4, actions = ['emotion'])

# %%
img5_result = DeepFace.analyze(img5, actions = ['emotion'])

# %%
img6_result = DeepFace.analyze(img6, actions = ['emotion'])

# %%
img7_result = DeepFace.analyze(img7, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 21 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FDB635FA60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(img1_result)
# Out:
# {'emotion': {'angry': 5.21414577960968, 'disgust': 0.004473413355299272, 'fear': 13.571520149707794, 'happy': 0.16458729514852166, 'sad': 19.593778252601624, 'surprise': 0.024540151935070753, 'neutral': 61.42696142196655}, 'dominant_emotion': 'neutral'}

# %% [markdown]
# #

# %%
print(img2_result)
# Out:
# {'emotion': {'angry': 2.6278774889038496, 'disgust': 5.459907340828511e-06, 'fear': 24.43679567794774, 'happy': 28.161890993230998, 'sad': 30.895193272542553, 'surprise': 0.0038052794929015333, 'neutral': 13.87443774190174}, 'dominant_emotion': 'sad'}

# %%
print(img3_result)
# Out:
# {'emotion': {'angry': 1.577210362313508e-06, 'disgust': 1.4415450441413596e-12, 'fear': 3.6686909510308396e-06, 'happy': 99.95880722999573, 'sad': 1.6376877631785192e-07, 'surprise': 2.069546525262922e-05, 'neutral': 0.041169431642629206}, 'dominant_emotion': 'happy'}

# %%
print(img4_result)
# Out:
# {'emotion': {'angry': 0.04601510299835354, 'disgust': 5.796828350668193e-07, 'fear': 0.16118213534355164, 'happy': 0.001668315235292539, 'sad': 99.78135824203491, 'surprise': 6.048924694468383e-08, 'neutral': 0.00977322124526836}, 'dominant_emotion': 'sad'}

# %%
print(img5_result)
# Out:
# {'emotion': {'angry': 8.106738854071458e-10, 'disgust': 6.292574210920039e-23, 'fear': 9.964247903117546e-11, 'happy': 99.5456397262597, 'sad': 7.374311601255168e-08, 'surprise': 0.4543151977250098, 'neutral': 4.756037980488786e-05}, 'dominant_emotion': 'happy'}

# %%
print(img6_result)
# Out:
# {'emotion': {'angry': 49.30350482463837, 'disgust': 0.5548294633626938, 'fear': 5.731037259101868, 'happy': 0.17160528805106878, 'sad': 30.048373341560364, 'surprise': 2.4170933291316032, 'neutral': 11.77356019616127}, 'dominant_emotion': 'angry'}

# %%
print(img7_result)
# Out:
# {'emotion': {'angry': 0.052738410886377096, 'disgust': 4.1049839083484585e-07, 'fear': 0.012367333692964166, 'happy': 76.5274167060852, 'sad': 0.23177741095423698, 'surprise': 0.0027312878955854103, 'neutral': 23.17296862602234}, 'dominant_emotion': 'happy'}

# %%
print(img1_result['dominant_emotion'])
# Out:
# neutral

# %%
print(img2_result['dominant_emotion'])
# Out:
# sad

# %%
print(img3_result['dominant_emotion'])
# Out:
# happy

# %%
print(img4_result['dominant_emotion'])
# Out:
# sad

# %%
print(img5_result['dominant_emotion'])
# Out:
# happy

# %%
print(img6_result['dominant_emotion'])
# Out:
# angry

# %%
print(img7_result['dominant_emotion'])
# Out:
# happy
