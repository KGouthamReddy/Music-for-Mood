# %% [markdown]
# <center><h2> Music For Mood </h2></center>

# %% [markdown]
# <h2>Trail 3</h2>

# %%
from deepface import DeepFace
import cv2

# %%
import matplotlib.pyplot as plt

# %%
# testing random male face expressions

# %%
img1 = cv2.imread('angry_m.jpg')
img2 = cv2.imread('sad_m.jpg')
img3 = cv2.imread('fear_m.jpg')
img4 = cv2.imread('surprise_m.jpg')
img5 = cv2.imread('happy_m.jpg')
img6 = cv2.imread('disgust_m.jpg')
img7 = cv2.imread('neutral_m.jpg')

# %%
plt.imshow(img1[:,:,::-1])
plt.title('img1')
plt.show()

# %%
plt.imshow(img2[:,:,::-1])
plt.title('img2')
plt.show()

# %%
plt.imshow(img3[:,:,::-1])
plt.title('img3')
plt.show()

# %%
plt.imshow(img4[:,:,::-1])
plt.title('img4')
plt.show()

# %%
plt.imshow(img5[:,:,::-1])
plt.title('img5')
plt.show()

# %%
plt.imshow(img6[:,:,::-1])
plt.title('img6')
plt.show()

# %%
plt.imshow(img7[:,:,::-1])
plt.title('img7')
plt.show()

# %%
img1_result = DeepFace.analyze(img1, actions = ['emotion'])

# %%
print(img1_result)
# Out:
# {'emotion': {'angry': 99.911046012231, 'disgust': 1.66035497900974e-24, 'fear': 6.422175585067723e-06, 'happy': 4.010246186120623e-08, 'sad': 0.023459901979007925, 'surprise': 8.530527412637494e-16, 'neutral': 0.0654899632316762}, 'dominant_emotion': 'angry'}

# %%
img2_result = DeepFace.analyze(img2, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DA6912D940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(img2_result)
# Out:
# {'emotion': {'angry': 0.20868158899247646, 'disgust': 2.1035365116439664e-08, 'fear': 0.0007286359505087603, 'happy': 19.466054439544678, 'sad': 47.050315141677856, 'surprise': 1.0584294329873956e-05, 'neutral': 33.27420651912689}, 'dominant_emotion': 'sad'}

# %%
img3_result = DeepFace.analyze(img3, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 24 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DA6810F670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(img3_result)
# Out:
# {'emotion': {'angry': 0.015302031533792615, 'disgust': 2.041187485701812e-05, 'fear': 0.00609508715569973, 'happy': 29.251375794410706, 'sad': 61.89654469490051, 'surprise': 0.09186702664010227, 'neutral': 8.738797903060913}, 'dominant_emotion': 'sad'}

# %%
img4_result = DeepFace.analyze(img4, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 22 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DA666BC3A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(img4_result)
# Out:
# {'emotion': {'angry': 5.015285964304894e-06, 'disgust': 6.929150314508373e-12, 'fear': 0.24179986212402582, 'happy': 3.3336584692733595e-05, 'sad': 3.2825241191858368e-06, 'surprise': 99.75816011428833, 'neutral': 1.4002123072121009e-08}, 'dominant_emotion': 'surprise'}

# %%
img5_result = DeepFace.analyze(img5, actions = ['emotion'])

# %%
print(img5_result)
# Out:
# {'emotion': {'angry': 8.368379821626049e-08, 'disgust': 6.159358600019147e-15, 'fear': 1.4207752488696216e-07, 'happy': 99.97973441956844, 'sad': 1.7235729149840578e-08, 'surprise': 1.926134033834496e-06, 'neutral': 0.020267907282939243}, 'dominant_emotion': 'happy'}

# %%
img6_result = DeepFace.analyze(img6, actions = ['emotion'])

# %%
print(img6_result)
# Out:
# {'emotion': {'angry': 99.07172311207331, 'disgust': 0.8002297975396868, 'fear': 0.008301982132395462, 'happy': 0.02740397793958818, 'sad': 0.07593741497955203, 'surprise': 8.292608833406872e-06, 'neutral': 0.016399704827146807}, 'dominant_emotion': 'angry'}

# %%
img7_result = DeepFace.analyze(img7, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 21 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DA6912DD30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DA6912DE50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(img7_result)
# Out:
# {'emotion': {'angry': 1.0877259075641632, 'disgust': 2.0548326495201108e-10, 'fear': 0.07880466873757541, 'happy': 3.796592125127063e-05, 'sad': 0.9119150228798389, 'surprise': 0.00027015191790269455, 'neutral': 97.92125225067139}, 'dominant_emotion': 'neutral'}

# %%
print(img1_result['dominant_emotion'])
# Out:
# angry

# %%
print(img2_result['dominant_emotion'])
# Out:
# sad

# %%
print(img3_result['dominant_emotion'])
# Out:
# sad

# %%
print(img4_result['dominant_emotion'])
# Out:
# surprise

# %%
print(img5_result['dominant_emotion'])
# Out:
# happy

# %%
print(img6_result['dominant_emotion'])
# Out:
# angry

# %%
print(img7_result['dominant_emotion'])
# Out:
# neutral
